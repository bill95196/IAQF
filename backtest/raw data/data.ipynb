# %% [markdown]
# # Training set

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
start, end = "2009-01-01", "2018-01-01"
Russell = yf.download("^RUA", start=start, end=end, progress= False)

# %%
vix = pd.read_excel("VIXCLS.xls")
m2 = pd.read_excel("WM2NS.xls")
unemp_rate = pd.read_excel("U2RATE.xls")
con_sentiment = pd.read_excel("UMCSENT.xls")
t10y2y = pd.read_excel("T10Y2Y.xls")
ppi = pd.read_excel("PPIACO.xls")
fed = pd.read_excel('FEDFUNDS.xls')
cpi = pd.read_excel("CPIAUCSL.xls")
dff = pd.read_excel('DFF.xls')
imp = pd.read_excel('IMPGS.xls')
#fip = pd.read_excel('FGVIP.xls')
#r2d = pd.read_excel('DEXCHUS.xls')

vix = vix.set_index('observation_date')
m2 = m2.set_index('observation_date')
unemp_rate = unemp_rate.set_index('observation_date')
con_sentiment = con_sentiment.set_index('observation_date')
t10y2y = t10y2y.set_index('observation_date')
ppi = ppi.set_index('observation_date')
fed = fed.set_index('observation_date')
cpi = cpi.set_index('observation_date')
dff = dff.set_index('observation_date')
imp = imp.set_index('observation_date')
#fip = fip.set_index('observation_date')
#r2d = r2d.set_index('observation_date')


vix = vix.resample('D').ffill()
m2 = m2.resample('D').ffill()
unemp_rate = unemp_rate.resample('D').ffill()
con_sentiment = con_sentiment.resample('D').ffill()
t10y2y = t10y2y.resample('D').ffill()
ppi = ppi.resample('D').ffill()
fed = fed.resample('D').ffill()
cpi = cpi.resample('D').ffill()
dff = dff.resample('D').ffill()
imp = imp.resample('D').ffill()
#fip = fip.resample('D').ffill()
#r2d = r2d.resample('D').ffill()

# %%
Russell = pd.merge(Russell,vix,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,m2,how='left',left_index=True, right_index=True)

Russell = pd.merge(Russell,unemp_rate,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,con_sentiment,how='left',left_index=True, right_index=True)


Russell = pd.merge(Russell,t10y2y,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,ppi,how='left',left_index=True, right_index=True)


Russell = pd.merge(Russell,fed,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,cpi,how='left',left_index=True, right_index=True)

Russell = pd.merge(Russell,dff,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,imp,how='left',left_index=True, right_index=True)

#Russell = pd.merge(Russell,fip,how='left',left_index=True, right_index=True)
#Russell = pd.merge(Russell,r2d,how='left',left_index=True, right_index=True)

# %%
Russell = Russell.drop(['Adj Close','Volume'],axis=1)

# %%
Russell.to_csv('data.csv')

# %%
Russell
# Out:
#                    Open         High          Low        Close  VIXCLS  \
# Date
# 2009-01-02   520.520020   537.960022   518.099976   536.260010   39.19
# 2009-01-05   536.260010   539.429993   528.820007   534.429993   39.08
# 2009-01-06   534.429993   544.020020   534.429993   539.780029   38.56
# 2009-01-07   539.520020   539.520020   520.650024   523.369995   43.39
# 2009-01-08   523.349976   525.989990   517.840027   525.880005   42.56
# ...                 ...          ...          ...          ...     ...
# 2017-12-22  1589.069946  1589.699951  1585.420044  1588.250000    9.90
# 2017-12-26  1587.520020  1588.300049  1585.630005  1587.000000   10.25
# 2017-12-27  1587.189941  1590.280029  1586.300049  1588.160034   10.47
# 2017-12-28  1588.609985  1591.530029  1587.949951  1591.449951   10.18
# 2017-12-29  1591.959961  1594.150024  1582.770020  1582.770020   11.04
#
#               WM2NS  unemployement_rate  consumer_sentiment  T10Y2Y  PPIACO  \
# Date
# 2009-01-02   8264.1                 4.8                61.2    1.58   171.2
# 2009-01-05   8332.0                 4.8                61.2    1.71   171.2
# 2009-01-06   8332.0                 4.8                61.2    1.71   171.2
# 2009-01-07   8332.0                 4.8                61.2    1.70   171.2
# 2009-01-08   8332.0                 4.8                61.2    1.64   171.2
# ...             ...                 ...                 ...     ...     ...
# 2017-12-22  13965.8                 2.0                95.9    0.57   196.3
# 2017-12-26  13934.4                 2.0                95.9    0.55   196.3
# 2017-12-27  13934.4                 2.0                95.9    0.53   196.3
# 2017-12-28  13934.4                 2.0                95.9    0.52   196.3
# 2017-12-29  13934.4                 2.0                95.9    0.51   196.3
#
#             FEDFUNDS  CPIAUCSL   DFF     IMPGS
# Date
# 2009-01-02      0.15   211.933  0.08  1932.761
# 2009-01-05      0.15   211.933  0.11  1932.761
# 2009-01-06      0.15   211.933  0.09  1932.761
# 2009-01-07      0.15   211.933  0.11  1932.761
# 2009-01-08      0.15   211.933  0.10  1932.761
# ...              ...       ...   ...       ...
# 2017-12-22      1.30   247.805  1.42  3034.004
# 2017-12-26      1.30   247.805  1.42  3034.004
# 2017-12-27      1.30   247.805  1.42  3034.004
# 2017-12-28      1.30   247.805  1.42  3034.004
# 2017-12-29      1.30   247.805  1.33  3034.004
#
# [2265 rows x 14 columns]

# %%
window_size = 20
# 计算移动平均
Russell['movingaverage'] = Russell['Close'].rolling(window=window_size).mean()
# 计算移动平均的百分比变化
Russell['pct_close'] = Russell['movingaverage'].pct_change()
# 根据条件设置 'label' 列
Russell['label'] = Russell['pct_close'].apply(lambda x: 1 if x > 0.0001 else (-1 if x < -0.0001 else 0)).shift(periods=-1)

Russell['M_20'] = np.log(Russell['Close']/Russell['Close'].shift(periods=-20))
Russell['M_15'] = np.log(Russell['Close']/Russell['Close'].shift(periods=-15))
Russell['M_10'] = np.log(Russell['Close']/Russell['Close'].shift(periods=-10))
Russell['M_5'] = np.log(Russell['Close']/Russell['Close'].shift(periods=-5))
Russell = Russell.dropna()
Russell.head(5)
# Out:
# C:\Users\Zaichuan\AppData\Local\Temp\ipykernel_11396\1796867176.py:5: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   Russell['pct_close'] = Russell['movingaverage'].pct_change()
#                   Open        High         Low       Close  VIXCLS   WM2NS  \
# Date
# 2009-02-02  476.260010  479.519989  468.859985  476.640015   45.52  8251.9
# 2009-02-03  476.630005  485.910004  474.420013  483.570007   43.06  8251.9
# 2009-02-04  483.309998  491.510010  478.519989  480.279999   43.85  8251.9
# 2009-02-05  480.260010  491.059998  473.459991  488.160004   43.73  8251.9
# 2009-02-06  487.989990  502.940002  487.989990  501.980011   43.37  8251.9
#
#             unemployement_rate  consumer_sentiment  T10Y2Y  PPIACO  ...  \
# Date                                                                ...
# 2009-02-02                 5.2                56.3    1.87   169.3  ...
# 2009-02-03                 5.2                56.3    1.93   169.3  ...
# 2009-02-04                 5.2                56.3    1.97   169.3  ...
# 2009-02-05                 5.2                56.3    1.97   169.3  ...
# 2009-02-06                 5.2                56.3    2.06   169.3  ...
#
#             CPIAUCSL   DFF     IMPGS  movingaverage  pct_close  label  \
# Date
# 2009-02-02   212.705  0.24  1932.761     496.427501  -0.005969   -1.0
# 2009-02-03   212.705  0.24  1932.761     493.884502  -0.005123   -1.0
# 2009-02-04   212.705  0.24  1932.761     490.909500  -0.006024   -1.0
# 2009-02-05   212.705  0.23  1932.761     489.149001  -0.003586   -1.0
# 2009-02-06   212.705  0.23  1932.761     487.954001  -0.002443   -1.0
#
#                 M_20      M_15      M_10       M_5
# Date
# 2009-02-02  0.171703  0.065434  0.042844 -0.052516
# 2009-02-03  0.161727  0.091856  0.059998  0.011251
# 2009-02-04  0.199695  0.101417  0.065789 -0.002620
# 2009-02-05  0.214673  0.138836  0.093176  0.011041
# 2009-02-06  0.253414  0.216502  0.157313  0.048259
#
# [5 rows x 21 columns]

# %%
Record = {}
for a in Russell.drop(columns=['label']):
    Record[a] = {}
    Record[a]['Max'] = max(Russell[a])
    Record[a]['Min'] = min(Russell[a])
    Russell[a] = (Russell[a]-min(Russell[a]))/(max(Russell[a])-min(Russell[a]))
Record
# Out:
# C:\Users\Zaichuan\AppData\Local\Temp\ipykernel_11396\3693363192.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Russell[a] = (Russell[a]-min(Russell[a]))/(max(Russell[a])-min(Russell[a]))
# {'Open': {'Max': 1559.3499755859375, 'Min': 389.5899963378906},
#  'High': {'Max': 1575.0799560546875, 'Min': 400.5},
#  'Low': {'Max': 1559.3499755859375, 'Min': 384.4100036621094},
#  'Close': {'Max': 1569.219970703125, 'Min': 389.6099853515625},
#  'VIXCLS': {'Max': 52.65, 'Min': 9.14},
#  'WM2NS': {'Max': 13825.5, 'Min': 8251.9},
#  'unemployement_rate': {'Max': 6.5, 'Min': 2.0},
#  'consumer_sentiment': {'Max': 100.7, 'Min': 55.8},
#  'T10Y2Y': {'Max': 2.91, 'Min': 0.58},
#  'PPIACO': {'Max': 208.3, 'Min': 168.1},
#  'FEDFUNDS': {'Max': 1.16, 'Min': 0.07},
#  'CPIAUCSL': {'Max': 247.284, 'Min': 212.495},
#  'DFF': {'Max': 1.16, 'Min': 0.04},
#  'IMPGS': {'Max': 3034.004, 'Min': 1879.461},
#  'movingaverage': {'Max': 1536.5944946289062, 'Min': 425.0834991455078},
#  'pct_close': {'Max': 0.010589882052007393, 'Min': -0.012609948495778123},
#  'M_20': {'Max': 0.2534140989541932, 'Min': -0.21708333829625093},
#  'M_15': {'Max': 0.22421908528061918, 'Min': -0.20333198175499137},
#  'M_10': {'Max': 0.19049750316854672, 'Min': -0.1982738347640358},
#  'M_5': {'Max': 0.1507183993902278, 'Min': -0.10808261678442911}}

# %%
X_train = Russell.drop(columns=['Open', 'High', 'Low', 'movingaverage', 'pct_close', 'label']).values
y_train = Russell['label'].values
unique, counts = np.unique(y_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {-1.0: 680, 0.0: 93, 1.0: 1435}

# %%
corr = Russell.drop(columns=['Open', 'High', 'Low', 'Close', 'movingaverage', 'pct_close', 'label']).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_561e0_row0_col0, #T_561e0_row1_col1, #T_561e0_row2_col2, #T_561e0_row3_col3, #T_561e0_row4_col4, #T_561e0_row5_col5, #T_561e0_row6_col6, #T_561e0_row6_col8, #T_561e0_row7_col7, #T_561e0_row8_col6, #T_561e0_row8_col8, #T_561e0_row9_col9, #T_561e0_row10_col10, #T_561e0_row11_col11, #T_561e0_row12_col12, #T_561e0_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_561e0_row0_col1, #T_561e0_row5_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_561e0_row0_col2, #T_561e0_row9_col3 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_561e0_row0_col3, #T_561e0_row2_col10, #T_561e0_row8_col12 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_561e0_row0_col4 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_561e0_row0_col5, #T_561e0_row0_col10, #T_561e0_row0_col11, #T_561e0_row0_col12, #T_561e0_row0_col13, #T_561e0_row1_col2, #T_561e0_row1_col4, #T_561e0_row2_col1, #T_561e0_row2_col3, #T_561e0_row2_col7, #T_561e0_row2_col9, #T_561e0_row4_col6, #T_561e0_row4_col8, #T_561e0_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_561e0_row0_col6, #T_561e0_row0_col8, #T_561e0_row9_col12 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_561e0_row0_col7, #T_561e0_row5_col0, #T_561e0_row9_col13 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_561e0_row0_col9, #T_561e0_row1_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col3, #T_561e0_row3_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col5, #T_561e0_row10_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_561e0_row1_col6 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col7, #T_561e0_row7_col1 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col8 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col9 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col10 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col11 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col12, #T_561e0_row2_col5, #T_561e0_row5_col13 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_561e0_row1_col13 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_561e0_row2_col0, #T_561e0_row6_col3, #T_561e0_row6_col7 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_561e0_row2_col4 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_561e0_row2_col6, #T_561e0_row2_col8, #T_561e0_row3_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_561e0_row2_col11, #T_561e0_row4_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_561e0_row2_col12 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_561e0_row2_col13 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_561e0_row3_col0, #T_561e0_row7_col2, #T_561e0_row9_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_561e0_row3_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_561e0_row3_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_561e0_row3_col6, #T_561e0_row3_col8 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_561e0_row3_col7, #T_561e0_row9_col7 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_561e0_row3_col9 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_561e0_row3_col10 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_561e0_row3_col11, #T_561e0_row7_col11 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_561e0_row3_col12, #T_561e0_row6_col10, #T_561e0_row8_col10 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_561e0_row3_col13, #T_561e0_row6_col11, #T_561e0_row7_col13 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_561e0_row4_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_561e0_row4_col2 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_561e0_row4_col3, #T_561e0_row6_col4, #T_561e0_row8_col4, #T_561e0_row9_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_561e0_row4_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_561e0_row4_col7, #T_561e0_row4_col13 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_561e0_row4_col9, #T_561e0_row8_col11 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_561e0_row4_col10 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_561e0_row4_col11 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_561e0_row4_col12 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_561e0_row5_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_561e0_row5_col2, #T_561e0_row10_col6, #T_561e0_row10_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_561e0_row5_col3, #T_561e0_row10_col3, #T_561e0_row11_col1, #T_561e0_row12_col7 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_561e0_row5_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_561e0_row5_col6, #T_561e0_row5_col8, #T_561e0_row5_col10 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_561e0_row5_col7, #T_561e0_row12_col13 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_561e0_row5_col9 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_561e0_row5_col11, #T_561e0_row9_col11 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_561e0_row6_col0, #T_561e0_row8_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_561e0_row6_col1 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_561e0_row6_col2, #T_561e0_row8_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_561e0_row6_col5, #T_561e0_row8_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_561e0_row6_col9, #T_561e0_row8_col9 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_561e0_row6_col12 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_561e0_row6_col13, #T_561e0_row8_col13 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_561e0_row7_col3 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_561e0_row7_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_561e0_row7_col5 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_561e0_row7_col6, #T_561e0_row7_col8, #T_561e0_row13_col12 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_561e0_row7_col9 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_561e0_row7_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_561e0_row7_col12, #T_561e0_row9_col4 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_561e0_row8_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_561e0_row8_col3, #T_561e0_row8_col7 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_561e0_row9_col1, #T_561e0_row10_col11 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_561e0_row9_col5 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_561e0_row9_col6, #T_561e0_row9_col8 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_561e0_row9_col10 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_561e0_row10_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_561e0_row10_col1, #T_561e0_row11_col7 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_561e0_row10_col4, #T_561e0_row12_col9 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_561e0_row10_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_561e0_row10_col7 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_561e0_row10_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_561e0_row10_col12 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_561e0_row10_col13 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_561e0_row11_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_561e0_row11_col2, #T_561e0_row12_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_561e0_row11_col3, #T_561e0_row13_col1, #T_561e0_row13_col7 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_561e0_row11_col4, #T_561e0_row12_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_561e0_row11_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_561e0_row11_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_561e0_row11_col8, #T_561e0_row12_col5, #T_561e0_row12_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_561e0_row11_col9 {

# %% [markdown]
# # Testing set

# %%
start, end = "2018-01-01", "2022-01-01"
Russell = yf.download("^RUA", start=start, end=end, progress= False)

# %%
vix = pd.read_excel("VIXCLS.xls")
m2 = pd.read_excel("WM2NS.xls")
unemp_rate = pd.read_excel("U2RATE.xls")
con_sentiment = pd.read_excel("UMCSENT.xls")
t10y2y = pd.read_excel("T10Y2Y.xls")
ppi = pd.read_excel("PPIACO.xls")
fed = pd.read_excel('FEDFUNDS.xls')
cpi = pd.read_excel("CPIAUCSL.xls")
dff = pd.read_excel('DFF.xls')
imp = pd.read_excel('IMPGS.xls')
#fip = pd.read_excel('FGVIP.xls')
#r2d = pd.read_excel('DEXCHUS.xls')

vix = vix.set_index('observation_date')
m2 = m2.set_index('observation_date')
unemp_rate = unemp_rate.set_index('observation_date')
con_sentiment = con_sentiment.set_index('observation_date')
t10y2y = t10y2y.set_index('observation_date')
ppi = ppi.set_index('observation_date')
fed = fed.set_index('observation_date')
cpi = cpi.set_index('observation_date')
dff = dff.set_index('observation_date')
imp = imp.set_index('observation_date')
#fip = fip.set_index('observation_date')
#r2d = r2d.set_index('observation_date')


vix = vix.resample('D').ffill()
m2 = m2.resample('D').ffill()
unemp_rate = unemp_rate.resample('D').ffill()
con_sentiment = con_sentiment.resample('D').ffill()
t10y2y = t10y2y.resample('D').ffill()
ppi = ppi.resample('D').ffill()
fed = fed.resample('D').ffill()
cpi = cpi.resample('D').ffill()
dff = dff.resample('D').ffill()
imp = imp.resample('D').ffill()
#fip = fip.resample('D').ffill()
#r2d = r2d.resample('D').ffill()

# %%
Russell = pd.merge(Russell,vix,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,m2,how='left',left_index=True, right_index=True)

Russell = pd.merge(Russell,unemp_rate,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,con_sentiment,how='left',left_index=True, right_index=True)


Russell = pd.merge(Russell,t10y2y,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,ppi,how='left',left_index=True, right_index=True)


Russell = pd.merge(Russell,fed,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,cpi,how='left',left_index=True, right_index=True)

Russell = pd.merge(Russell,dff,how='left',left_index=True, right_index=True)
Russell = pd.merge(Russell,imp,how='left',left_index=True, right_index=True)

#Russell = pd.merge(Russell,fip,how='left',left_index=True, right_index=True)
#Russell = pd.merge(Russell,r2d,how='left',left_index=True, right_index=True)

# %%
Russell = Russell.drop(['Adj Close','Volume'],axis=1)
window_size = 20
# 计算移动平均
Russell['movingaverage'] = Russell['Close'].rolling(window=window_size).mean()

# 计算移动平均的百分比变化
Russell['pct_close'] = Russell['movingaverage'].pct_change()

# 根据条件设置 'label' 列
Russell['label'] = Russell['pct_close'].apply(lambda x: 1 if x > 0.0001 else (-1 if x < -0.0001 else 0)).shift(periods=-1)

Russell['M_20'] = np.log(Russell['Close']/Russell['Close'].shift(periods=-20))
Russell['M_15'] = np.log(Russell['Close']/Russell['Close'].shift(periods=-15))
Russell['M_10'] = np.log(Russell['Close']/Russell['Close'].shift(periods=-10))
Russell['M_5'] = np.log(Russell['Close']/Russell['Close'].shift(periods=-5))
Russell = Russell.dropna()
Russell.head(5)
# Out:
# C:\Users\Zaichuan\AppData\Local\Temp\ipykernel_11396\1800909905.py:7: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   Russell['pct_close'] = Russell['movingaverage'].pct_change()
#                    Open         High          Low        Close  VIXCLS  \
# Date
# 2018-01-31  1664.949951  1674.709961  1658.819946  1664.680054   13.54
# 2018-02-01  1664.199951  1671.630005  1659.119995  1664.369995   13.47
# 2018-02-02  1660.520020  1660.520020  1628.540039  1629.560059   17.31
# 2018-02-05  1627.119995  1630.130005  1560.310059  1564.660034   37.32
# 2018-02-06  1562.699951  1593.530029  1538.540039  1589.780029   29.98
#
#               WM2NS  unemployement_rate  consumer_sentiment  T10Y2Y  PPIACO  \
# Date
# 2018-01-31  13745.1                 2.0                95.7    0.58   197.9
# 2018-02-01  13745.1                 2.0                99.7    0.62   199.3
# 2018-02-02  13745.1                 2.0                99.7    0.69   199.3
# 2018-02-05  13839.2                 2.0                99.7    0.69   199.3
# 2018-02-06  13839.2                 2.0                99.7    0.69   199.3
#
#             ...  CPIAUCSL   DFF     IMPGS  movingaverage  pct_close  label  \
# Date        ...
# 2018-01-31  ...   248.859  1.34  3093.299    1650.664001   0.002089    1.0
# 2018-02-01  ...   249.529  1.42  3093.299    1653.623004   0.001793    1.0
# 2018-02-02  ...   249.529  1.42  3093.299    1654.550006   0.000561   -1.0
# 2018-02-05  ...   249.529  1.42  3093.299    1651.714508  -0.001714   -1.0
# 2018-02-06  ...   249.529  1.42  3093.299    1649.986011  -0.001046   -1.0
#
#                 M_20      M_15      M_10       M_5
# Date
# 2018-01-31  0.051468  0.041437  0.043593  0.050197
# 2018-02-01  0.044845  0.025947  0.031642  0.087282
# 2018-02-02  0.012940 -0.005880  0.009873  0.052283
# 2018-02-05 -0.031400 -0.033578 -0.024819 -0.001597
# 2018-02-06 -0.015944 -0.006502 -0.004112  0.011552
#
# [5 rows x 21 columns]

# %%
backtesting_data = Russell[['Open', 'High', 'Low', 'Close']]

# %%
for a in Russell.drop(columns=['label']):
    Russell[a] = (Russell[a]-Record[a]['Min'])/(Record[a]['Max']-Record[a]['Min'])
X_test = Russell.drop(columns=['Open', 'High', 'Low', 'movingaverage', 'pct_close', 'label']).values
y_test = Russell['label'].values
unique, counts = np.unique(y_test, return_counts=True)
dict(zip(unique, counts))
# Out:
# {-1.0: 256, 0.0: 28, 1.0: 647}

# %% [markdown]
# # Training classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import accuracy_score

param_grid = {
    'n_estimators': [32, 64, 100, 250, 500],
    'max_depth': [10, 15, 30, 50],
    'min_samples_leaf': [1, 5, 10, 30, 50, 75, 100],
    'max_samples': [0.6, 0.7, 0.8]
}

classifier = RandomForestClassifier()
tscv = TimeSeriesSplit(n_splits=5)
grid_search = GridSearchCV(estimator=classifier, param_grid=param_grid, cv=tscv, n_jobs=-1, verbose=3)
grid_search.fit(X_train, y_train)
best_params = grid_search.best_params_
best_params
# Out:
# Fitting 5 folds for each of 420 candidates, totalling 2100 fits
# {'max_depth': 30,
#  'max_samples': 0.6,
#  'min_samples_leaf': 30,
#  'n_estimators': 32}

# %%
classifier = RandomForestClassifier(n_estimators=best_params['n_estimators'],
                                    max_depth=best_params['max_depth'],
                                    min_samples_leaf=best_params['min_samples_leaf'], 
                                    max_samples=best_params['max_samples'], 
                                    random_state=10)
classifier.fit(X_train, y_train)
y_hat = classifier.predict(X_test)
unique, counts = np.unique(y_hat, return_counts=True)
print(dict(zip(unique, counts)))
accuracy_score(y_test, y_hat)
# Out:
# {-1.0: 153, 1.0: 778}
# 0.7325456498388829

# %%
imp = classifier.feature_importances_
feature_names = [f"{i}" for i in Russell.drop(columns=['Open', 'High', 'Low', 'movingaverage', 'pct_close', 'label']).columns.tolist()]
forest_importances = pd.Series(imp, index=feature_names)
forest_importances.sort_values(ascending=False)
forest_importances
# Out:
# Close                 0.057363
# VIXCLS                0.191291
# WM2NS                 0.048476
# unemployement_rate    0.029905
# consumer_sentiment    0.144633
# T10Y2Y                0.034313
# PPIACO                0.041051
# FEDFUNDS              0.036159
# CPIAUCSL              0.063214
# DFF                   0.026596
# IMPGS                 0.040314
# M_20                  0.059528
# M_15                  0.086720
# M_10                  0.069403
# M_5                   0.071033
# dtype: float64

# %%
backtesting_data['index'] = y_hat
backtesting_data.to_csv('backtesting_data.csv')
backtesting_data.head()
# Out:
# C:\Users\Zaichuan\AppData\Local\Temp\ipykernel_11396\84262144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   backtesting_data['index'] = y_hat
#                    Open         High          Low        Close  index
# Date
# 2018-01-31  1664.949951  1674.709961  1658.819946  1664.680054    1.0
# 2018-02-01  1664.199951  1671.630005  1659.119995  1664.369995    1.0
# 2018-02-02  1660.520020  1660.520020  1628.540039  1629.560059    1.0
# 2018-02-05  1627.119995  1630.130005  1560.310059  1564.660034    1.0
# 2018-02-06  1562.699951  1593.530029  1538.540039  1589.780029    1.0

# %%
backtesting_data.tail()
# Out:
#                    Open         High          Low        Close  index
# Date
# 2021-11-26  2771.959961  2771.959961  2703.139893  2709.729980    1.0
# 2021-11-29  2711.520020  2752.360107  2711.520020  2739.790039    1.0
# 2021-11-30  2738.840088  2738.840088  2682.429932  2685.540039    1.0
# 2021-12-01  2687.780029  2734.919922  2645.459961  2646.449951    1.0
# 2021-12-02  2646.280029  2698.939941  2645.469971  2688.850098    1.0
