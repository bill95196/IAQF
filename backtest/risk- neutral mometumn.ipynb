# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import linregress

# %%
def compute_RS_rolling(series, window_size=30):
    n = len(series)
    RS = []
    dates = []
    
    for start in range(0, n - window_size + 1):
        end = start + window_size
        segment = series[start:end]
        mean = segment.mean()
        cumulative_deviation = np.cumsum(segment - mean)
        R = np.max(cumulative_deviation) - np.min(cumulative_deviation)
        S = segment.std()
        if S != 0:
            RS.append(R / S)
            dates.append(series.index[end-1])
    
    return dates, RS

def hurst_exponent_rolling(series, window_size=30):
    dates, RS = compute_RS_rolling(series, window_size)
    if not RS:
        return pd.DataFrame(columns=['Date', 'Hurst Exponent'])
    

    hurst_values = []
    for rs in RS:
        hurst_values.append(np.log(rs)/np.log(window_size))
    
    results_df = pd.DataFrame({'Date': dates, 'Hurst Exponent': hurst_values})
    return results_df

# %%
file_path= '/Users/jinnia/Desktop/data/sp6m_6.csv'
df = pd.read_csv(file_path, parse_dates=['idt'])
df.set_index('idt', inplace=True)

timeseries = df['mu']
results_df = hurst_exponent_rolling(timeseries, 30)
print(results_df)
# Out:
#           Date  Hurst Exponent
# 0   2008-03-31        0.736254
# 1   2008-04-15        0.744547
# 2   2008-04-30        0.750150
# 3   2008-05-15        0.754461
# 4   2008-05-30        0.756937
# ..         ...             ...
# 651 2023-12-13        0.697537
# 652 2023-12-20        0.716123
# 653 2023-12-27        0.718466
# 654 2024-01-03        0.723428
# 655 2024-01-10        0.729150
#
# [656 rows x 2 columns]

# %%
hurst_avg = results_df['Hurst Exponent'].mean()
results_df['index'] = results_df['Hurst Exponent'].apply(lambda x: -1 if x > hurst_avg else 1)

# %%
sp_df = pd.read_csv('/Users/jinnia/Desktop/data/sp.csv', parse_dates=['Date'])
sp_df.set_index('Date', inplace=True)
sp_selected = sp_df[['Open','High','Low','Close']]
merged_df = results_df.join(sp_selected, on='Date', how='left')
merged_df.dropna(subset=['Open'], inplace=True)
merged_df = merged_df.drop('Hurst Exponent', axis=1)

print(merged_df)
# Out:
#           Date  index         Open         High          Low        Close
# 0   2008-03-31     -1  1315.920044  1328.520020  1312.810059  1322.699951
# 1   2008-04-15     -1  1331.719971  1337.719971  1324.349976  1334.430054
# 2   2008-04-30     -1  1391.219971  1404.569946  1384.250000  1385.589966
# 3   2008-05-15     -1  1408.359985  1424.400024  1406.869995  1423.569946
# 4   2008-05-30     -1  1398.359985  1404.459961  1398.079956  1400.380005
# ..         ...    ...          ...          ...          ...          ...
# 597 2022-11-30     -1  3957.179932  4080.110107  3938.580078  4080.110107
# 598 2022-12-07     -1  3933.280029  3957.570068  3922.679932  3933.919922
# 599 2022-12-14     -1  4015.540039  4053.760010  3965.649902  3995.320068
# 600 2022-12-21     -1  3839.489990  3889.820068  3839.489990  3878.439941
# 601 2022-12-28     -1  3829.560059  3848.320068  3780.780029  3783.219971
#
# [601 rows x 6 columns]

# %%
cols = [col for col in merged_df.columns if col != 'index']
cols.append('index')
merged_df = merged_df[cols]
merged_df
# Out:
#           Date         Open         High          Low        Close  index
# 0   2008-03-31  1315.920044  1328.520020  1312.810059  1322.699951     -1
# 1   2008-04-15  1331.719971  1337.719971  1324.349976  1334.430054     -1
# 2   2008-04-30  1391.219971  1404.569946  1384.250000  1385.589966     -1
# 3   2008-05-15  1408.359985  1424.400024  1406.869995  1423.569946     -1
# 4   2008-05-30  1398.359985  1404.459961  1398.079956  1400.380005     -1
# ..         ...          ...          ...          ...          ...    ...
# 597 2022-11-30  3957.179932  4080.110107  3938.580078  4080.110107     -1
# 598 2022-12-07  3933.280029  3957.570068  3922.679932  3933.919922     -1
# 599 2022-12-14  4015.540039  4053.760010  3965.649902  3995.320068     -1
# 600 2022-12-21  3839.489990  3889.820068  3839.489990  3878.439941     -1
# 601 2022-12-28  3829.560059  3848.320068  3780.780029  3783.219971     -1
#
# [601 rows x 6 columns]

# %%
merged_df.to_csv('/Users/jinnia/Desktop/backtest/raw data/backtesting_data.csv', index=False)

# %%
# %run /Users/jinnia/Desktop/backtest/cringe.py
# Out:
# root - INFO - 启动资金: 1000000.00
# root - INFO - 期末价值: 1196743.47
# root - INFO - Annual Return: 0.03558292413943511
# root - INFO - Sharp Ratio: 0.5081650598749003
# root - INFO - Max DrawDown: 83.91521081804929%
# 2008-04-15 23:59:59.999989,卖出:backtesting_data
# 价格:1331.72,                发起：sell,                成本: -503390.15,                手续费10.07
# 2010-10-15 23:59:59.999989,买入:backtesting_data
# 价格:1177.47,                发起：close,                成本:-503390.15,                手续费:8.90
# 2010-10-15 23:59:59.999989,买入:backtesting_data
# 价格:1177.47,                发起：buy,                成本:552233.42,                手续费:11.04
# 2010-10-15 23:59:59.999989,策略收益：
# 毛收益 58306.50, 净收益 58287.53
# 2013-01-24 23:59:59.999989,卖出:backtesting_data
# 价格:1494.81,                发起：close,                成本: 552233.42,                手续费14.02
# 2013-01-24 23:59:59.999989,卖出:backtesting_data
# 价格:1494.81,                发起：sell,                成本: -606892.88,                手续费12.14
# 2013-01-24 23:59:59.999989,策略收益：
# 毛收益 148832.50, 净收益 148807.44
# 2013-02-07 23:59:59.999989,买入:backtesting_data
# 价格:1512.12,                发起：close,                成本:-606892.88,                手续费:12.28
# 2013-02-07 23:59:59.999989,买入:backtesting_data
# 价格:1512.12,                发起：buy,                成本:609384.36,                手续费:12.19
# 2013-02-07 23:59:59.999989,策略收益：
# 毛收益 -7027.83, 净收益 -7052.25
# 2014-05-15 23:59:59.999989,卖出:backtesting_data
# 价格:1888.16,                发起：close,                成本: 609384.36,                手续费15.22
# 2014-05-15 23:59:59.999989,卖出:backtesting_data
# 价格:1888.16,                发起：sell,                成本: -675961.29,                手续费13.52
# 2014-05-15 23:59:59.999989,策略收益：
# 毛收益 151544.14, 净收益 151516.73
# 2014-05-22 23:59:59.999989,买入:backtesting_data
# 价格:1888.19,                发起：close,                成本:-675961.29,                手续费:13.52
# 2014-05-22 23:59:59.999989,买入:backtesting_data
# 价格:1888.19,                发起：buy,                成本:683524.76,                手续费:13.67
# 2014-05-22 23:59:59.999989,策略收益：
# 毛收益 -10.71, 净收益 -37.75
# 2015-02-04 23:59:59.999989,卖出:backtesting_data
# 价格:2048.86,                发起：close,                成本: 683524.76,                手续费14.83
# 2015-02-04 23:59:59.999989,卖出:backtesting_data
# 价格:2048.86,                发起：sell,                成本: -710954.46,                手续费14.22
# 2015-02-04 23:59:59.999989,策略收益：
# 毛收益 58162.60, 净收益 58134.10
# 2015-04-15 23:59:59.999989,买入:backtesting_data
# 价格:2097.82,                发起：close,                成本:-710954.46,                手续费:14.56
# 2015-04-15 23:59:59.999989,买入:backtesting_data
# 价格:2097.82,                发起：buy,                成本:702769.72,                手续费:14.06
# 2015-04-15 23:59:59.999989,策略收益：
# 毛收益 -16989.11, 净收益 -17017.88
# 2017-03-08 23:59:59.999989,卖出:backtesting_data
# 价格:2369.81,                发起：close,                成本: 702769.72,                手续费15.88
# 2017-03-08 23:59:59.999989,卖出:backtesting_data
# 价格:2369.81,                发起：sell,                成本: -737010.93,                手续费14.74
# 2017-03-08 23:59:59.999989,策略收益：
# 毛收益 91116.65, 净收益 91086.71
# 2020-02-26 23:59:59.999989,买入:backtesting_data
# 价格:3139.90,                发起：close,                成本:-737010.93,                手续费:19.53
# 2020-02-26 23:59:59.999989,买入:backtesting_data
# 价格:3139.90,                发起：buy,                成本:540062.78,                手续费:10.80
# 2020-02-26 23:59:59.999989,策略收益：
# 毛收益 -239497.94, 净收益 -239532.21
# 2020-03-25 23:59:59.999989,卖出:backtesting_data
# 价格:2457.77,                发起：close,                成本: 540062.78,                手续费8.45
# 2020-03-25 23:59:59.999989,卖出:backtesting_data
# 价格:2457.77,                发起：sell,                成本: -570202.64,                手续费11.40
# 2020-03-25 23:59:59.999989,策略收益：
# 毛收益 -117326.34, 净收益 -117345.60
# 2020-09-17 23:59:59.999989,买入:backtesting_data
# 价格:3346.86,                发起：close,                成本:-570202.64,                手续费:15.53
# 2020-09-17 23:59:59.999989,买入:backtesting_data
# 价格:3346.86,                发起：buy,                成本:445132.39,                手续费:8.90
# 2020-09-17 23:59:59.999989,策略收益：
# 毛收益 -206268.90, 净收益 -206295.83
# 2021-01-27 23:59:59.999989,卖出:backtesting_data
# 价格:3836.83,                发起：close,                成本: 445132.39,                手续费10.21
# 2021-01-27 23:59:59.999989,卖出:backtesting_data
# 价格:3836.83,                发起：sell,                成本: -491114.25,                手续费9.82
# 2021-01-27 23:59:59.999989,策略收益：
# 毛收益 65166.01, 净收益 65146.90
# 2021-04-07 23:59:59.999989,买入:backtesting_data
# 价格:4074.29,                发起：close,                成本:-491114.25,                手续费:10.43
# 2021-04-07 23:59:59.999989,买入:backtesting_data
# 价格:4074.29,                发起：buy,                成本:492989.09,                手续费:9.86
# 2021-04-07 23:59:59.999989,策略收益：
# 毛收益 -30394.88, 净收益 -30415.13
# 2021-06-09 23:59:59.999989,卖出:backtesting_data
# 价格:4232.99,                发起：close,                成本: 492989.09,                手续费10.24
# 2021-06-09 23:59:59.999989,卖出:backtesting_data
# 价格:4232.99,                发起：sell,                成本: -486793.88,                手续费9.74
# 2021-06-09 23:59:59.999989,策略收益：
# 毛收益 19202.72, 净收益 19182.62
# 2021-06-16 23:59:59.999989,买入:backtesting_data
# 价格:4248.87,                发起：close,                成本:-486793.88,                手续费:9.77
# 2021-06-16 23:59:59.999989,买入:backtesting_data
# 价格:4248.87,                发起：buy,                成本:488620.06,                手续费:9.77
# 2021-06-16 23:59:59.999989,策略收益：
# 毛收益 -1826.19, 净收益 -1845.69
# 2021-08-04 23:59:59.999989,卖出:backtesting_data
# 价格:4415.95,                发起：close,                成本: 488620.06,                手续费10.16
# 2021-08-04 23:59:59.999989,卖出:backtesting_data
# 价格:4415.95,                发起：sell,                成本: -494586.42,                手续费9.89
# 2021-08-04 23:59:59.999989,策略收益：
# 毛收益 19214.21, 净收益 19194.28
# 2021-08-25 23:59:59.999989,买入:backtesting_data
# 价格:4490.45,                发起：close,                成本:-494586.42,                手续费:10.06
# 2021-08-25 23:59:59.999989,买入:backtesting_data
# 价格:4490.45,                发起：buy,                成本:502930.42,                手续费:10.06
# 2021-08-25 23:59:59.999989,策略收益：
# 毛收益 -8344.00, 净收益 -8363.95
# 2021-12-08 23:59:59.999989,卖出:backtesting_data
# 价格:4690.86,                发起：close,                成本: 502930.42,                手续费10.51
# 2021-12-08 23:59:59.999989,卖出:backtesting_data
# 价格:4690.86,                发起：sell,                成本: -511303.73,                手续费10.23
# 2021-12-08 23:59:59.999989,策略收益：
# 毛收益 22445.88, 净收益 22425.32
# 2021-12-29 23:59:59.999989,买入:backtesting_data
# 价格:4788.64,                发起：close,                成本:-511303.73,                手续费:10.44
# 2021-12-29 23:59:59.999989,买入:backtesting_data
# 价格:4788.64,                发起：buy,                成本:512384.49,                手续费:10.25
# 2021-12-29 23:59:59.999989,策略收益：
# 毛收益 -10658.05, 净收益 -10678.72
# 2022-02-02 23:59:59.999989,卖出:backtesting_data
# 价格:4566.39,                发起：close,                成本: 512384.49,                手续费9.77
# 2022-02-02 23:59:59.999989,卖出:backtesting_data
# 价格:4566.39,                发起：sell,                成本: -493170.13,                手续费9.86
# 2022-02-02 23:59:59.999989,策略收益：
# 毛收益 -23780.75, 净收益 -23800.77
# 2022-02-23 23:59:59.999989,买入:backtesting_data
# 价格:4324.93,                发起：close,                成本:-493170.13,                手续费:9.34
# 2022-02-23 23:59:59.999989,买入:backtesting_data
# 价格:4324.93,                发起：buy,                成本:471417.39,                手续费:9.43
# 2022-02-23 23:59:59.999989,策略收益：
# 毛收益 26077.68, 净收益 26058.47
# 2022-05-04 23:59:59.999989,卖出:backtesting_data
# 价格:4181.18,                发起：close,                成本: 471417.39,                手续费9.11
# 2022-05-04 23:59:59.999989,卖出:backtesting_data
# 价格:4181.18,                发起：sell,                成本: -489198.08,                手续费9.78
# 2022-05-04 23:59:59.999989,策略收益：
# 毛收益 -15668.75, 净收益 -15687.29
# 2022-05-25 23:59:59.999989,买入:backtesting_data
# 价格:3929.59,                发起：close,                成本:-489198.08,                手续费:9.20
# 2022-05-25 23:59:59.999989,买入:backtesting_data
# 价格:3929.59,                发起：buy,                成本:502987.53,                手续费:10.06
# 2022-05-25 23:59:59.999989,策略收益：
# 毛收益 29436.04, 净收益 29417.06
# 2022-06-01 23:59:59.999989,卖出:backtesting_data
# 价格:4149.78,                发起：close,                成本: 502987.53,                手续费10.62
# 2022-06-01 23:59:59.999989,卖出:backtesting_data
# 价格:4149.78,                发起：sell,                成本: -527022.03,                手续费10.54
# 2022-06-01 23:59:59.999989,策略收益：
# 毛收益 28184.28, 净收益 28163.60
# 2022-07-06 23:59:59.999989,买入:backtesting_data
# 价格:3831.98,                发起：close,                成本:-527022.03,                手续费:9.73
# 2022-07-06 23:59:59.999989,买入:backtesting_data
# 价格:3831.98,                发起：buy,                成本:540309.18,                手续费:10.81
# 2022-07-06 23:59:59.999989,策略收益：
# 毛收益 40360.58, 净收益 40340.30
# 2022-08-17 23:59:59.999989,卖出:backtesting_data
# 价格:4280.40,                发起：close,                成本: 540309.18,                手续费12.07
# 2022-08-17 23:59:59.999989,卖出:backtesting_data
# 价格:4280.40,                发起：sell,                成本: -573573.59,                手续费11.47
# 2022-08-17 23:59:59.999989,策略收益：
# 毛收益 63227.21, 净收益 63204.33
# backtesting_data
# <div id='58acab8e-21c9-49cc-b123-a4fe3461440b'></div>
# <div id='080ac5c4-f438-439a-8d22-947c984854a5'></div>
# <div id='25e9c3b4-14e2-4f94-a0ed-4b223f9bb4db'></div>
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# H is typically above 0.5 in times of smooth returns and low volatility, indicating positive expected autocorrelation.
# In times of nervousness, market expectations either revert to a random walk (H = 0.5) or lead to negative ex-ante momentum.
# https://doi.org/10.1016/j.frl.2019.101347
