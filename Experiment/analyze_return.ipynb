# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import yfinance as yf

# %%
def name_ticker_pair():
    pairs = {"silver":"SI=F", 
             "bac":"BAC", 
             "citi":"C", 
             "corn":"ZC=F", 
             "euro":"EURUSD=X", 
             "gold":"GC=F", 
             "iyr":"IYR", 
             "oil":"CL=F", 
             "pound":"GBPUSD=X", 
             "soybns":"ZS=F", 
             "tr5yr":"^FVX", 
             "tr10yr":"^TNX", 
             "wheat":"ZW=F", 
             "yen":"JPY=X"}
    return pairs

# %%
bac_yf = yf.download('BAC', start = '2010-01-05', end = '2024-01-22', progress=False)
citi_yf = yf.download('C', start = '2010-01-05', end = '2024-01-22', progress=False)

print(bac_yf.shape, citi_yf.shape)
# Out:
# (3534, 6) (3534, 6)

# %%
# get RND stats
bac_rnd = pd.read_csv('data/bac_3.csv')
citi_rnd = pd.read_csv('data/citi_3.csv')

print(bac_rnd.shape, citi_rnd.shape)
# Out:
# (613, 14) (613, 14)

# %%
# transform/clean data
bac_rnd['Date'] =pd.to_datetime(bac_rnd['idt'], format='%m/%d/%y')
bac_rnd = bac_rnd.set_index('Date')
bac_rnd.drop('idt',axis= 1, inplace=True)

citi_rnd['Date'] =pd.to_datetime(citi_rnd['idt'], format='%m/%d/%y')
citi_rnd = citi_rnd.set_index('Date')
citi_rnd.drop('idt',axis= 1, inplace=True)

# %%
# add two more extreme probability features
bac_rnd['dec_plus_inc'] = bac_rnd['prDec'] + bac_rnd['prInc']
bac_rnd['dec_minus_inc'] = bac_rnd['prDec'] - bac_rnd['prInc']

citi_rnd['dec_plus_inc'] = citi_rnd['prDec'] + citi_rnd['prInc']
citi_rnd['dec_minus_inc'] = citi_rnd['prDec'] - citi_rnd['prInc']

# %%
# for BAC:
fut_ret = pd.DataFrame()
for day in range(10,100,10):
    fut_ret[f'{day}day_ret'] =  (bac_yf['Close'].shift(-day) - bac_yf['Close'])/bac_yf['Close']
fut_ret
# Out:
#             10day_ret  20day_ret  30day_ret  40day_ret  50day_ret  60day_ret  \
# Date
# 2010-01-05   0.017901  -0.041358  -0.019753   0.012346   0.054321   0.113580
# 2010-01-06  -0.056132  -0.100061  -0.031116   0.018914   0.026236   0.106162
# 2010-01-07  -0.119906  -0.113999  -0.042528  -0.011223   0.001772   0.092144
# 2010-01-08  -0.107271  -0.137068  -0.050060   0.001192   0.020858   0.109654
# 2010-01-11  -0.127584  -0.145304  -0.035440   0.010632   0.037803   0.101595
# ...               ...        ...        ...        ...        ...        ...
# 2024-01-12        NaN        NaN        NaN        NaN        NaN        NaN
# 2024-01-16        NaN        NaN        NaN        NaN        NaN        NaN
# 2024-01-17        NaN        NaN        NaN        NaN        NaN        NaN
# 2024-01-18        NaN        NaN        NaN        NaN        NaN        NaN
# 2024-01-19        NaN        NaN        NaN        NaN        NaN        NaN
#
#             70day_ret  80day_ret  90day_ret
# Date
# 2010-01-05   0.136420   0.100617   0.008642
# 2010-01-06   0.122026   0.101891  -0.002440
# 2010-01-07   0.099232   0.037212  -0.057885
# 2010-01-08   0.089392   0.044696  -0.028010
# 2010-01-11   0.095097  -0.038393  -0.096279
# ...               ...        ...        ...
# 2024-01-12        NaN        NaN        NaN
# 2024-01-16        NaN        NaN        NaN
# 2024-01-17        NaN        NaN        NaN
# 2024-01-18        NaN        NaN        NaN
# 2024-01-19        NaN        NaN        NaN
#
# [3534 rows x 9 columns]

# %%
feature = ['mu', 'sd', 'skew', 'kurt', 'p10', 'p50','p90','prDec','prInc','dec_plus_inc', 'dec_minus_inc']
feature_df = bac_rnd[feature].copy()
feature_df.describe()
# Out:
#                mu          sd        skew        kurt         p10         p50  \
# count  613.000000  613.000000  613.000000  613.000000  613.000000  613.000000
# mean    -0.005387    0.150914   -0.556849    1.051346   -0.198459    0.007936
# std      0.007952    0.048331    0.219521    0.460131    0.068411    0.010805
# min     -0.046960    0.094230   -1.196640    0.213820   -0.776080   -0.017250
# 25%     -0.008630    0.120100   -0.718890    0.687390   -0.223270    0.002160
# 50%     -0.004210    0.137250   -0.543890    1.009430   -0.179300    0.006560
# 75%     -0.000770    0.167710   -0.393420    1.314370   -0.156240    0.012340
# max      0.054560    0.475820    0.220050    2.653120   -0.119170    0.103450
#
#               p90       prDec       prInc  dec_plus_inc  dec_minus_inc
# count  613.000000  613.000000  613.000000    613.000000     613.000000
# mean     0.168623    0.093237    0.065635      0.158873       0.027602
# std      0.047780    0.045057    0.051612      0.094778       0.020125
# min      0.110480    0.027360    0.009180      0.040540      -0.141100
# 25%      0.138700    0.059570    0.032160      0.093320       0.020250
# 50%      0.154590    0.081550    0.048900      0.131150       0.027980
# 75%      0.185590    0.118470    0.083680      0.202180       0.038460
# max      0.491880    0.272370    0.380230      0.638360       0.079670

# %%
df = feature_df.merge(fut_ret, left_index=True,right_index=True,how='left')
df
# Out:
#                  mu       sd     skew     kurt      p10      p50      p90  \
# Date
# 2010-01-15 -0.02514  0.18210 -0.38173  0.85192 -0.25389 -0.01634  0.19272
# 2010-01-29 -0.02194  0.21265 -0.79513  1.61552 -0.28826  0.00001  0.21786
# 2010-02-12 -0.01699  0.21625 -0.86181  1.83248 -0.28670  0.00720  0.22358
# 2010-02-26 -0.00965  0.17893 -0.70108  1.40641 -0.23570  0.00776  0.19373
# 2010-03-15  0.00006  0.17357 -0.71889  1.63480 -0.21657  0.01649  0.19608
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-12-13  0.00352  0.11858 -0.55862  1.13971 -0.14633  0.01278  0.14065
# 2023-12-20  0.00081  0.12808 -0.29318  0.71192 -0.16021  0.00599  0.15502
# 2023-12-27  0.00169  0.12350 -0.40609  0.92177 -0.15376  0.00863  0.14759
# 2024-01-03  0.00161  0.12852 -0.40098  0.84767 -0.16048  0.00854  0.15460
# 2024-01-10  0.00129  0.12306 -0.37164  0.89001 -0.15312  0.00741  0.14736
#
#               prDec    prInc  dec_plus_inc  dec_minus_inc  10day_ret  \
# Date
# 2010-01-15  0.14898  0.09307       0.24205        0.05591  -0.051661
# 2010-01-29  0.16750  0.12009       0.28759        0.04741  -0.048090
# 2010-02-12  0.16404  0.12713       0.29117        0.03691   0.156401
# 2010-02-26  0.12882  0.09233       0.22115        0.03649   0.011405
# 2010-03-15  0.11325  0.09545       0.20870        0.01780   0.070623
# ...             ...      ...           ...            ...        ...
# 2023-12-13  0.05447  0.03384       0.08831        0.02063   0.057428
# 2023-12-20  0.06324  0.05067       0.11391        0.01257   0.043966
# 2023-12-27  0.05846  0.04262       0.10108        0.01584  -0.020390
# 2024-01-03  0.06398  0.04890       0.11288        0.01508  -0.053683
# 2024-01-10  0.05747  0.04306       0.10053        0.01441        NaN
#
#             20day_ret  30day_ret  40day_ret  50day_ret  60day_ret  70day_ret  \
# Date
# 2010-01-15  -0.067651   0.012300   0.047356   0.092251   0.193112   0.093481
# 2010-01-29   0.100790   0.110013   0.188406   0.229908   0.150856   0.130435
# 2010-02-12   0.166090   0.248443   0.292042   0.208997   0.187543   0.071972
# 2010-02-26   0.074430   0.120048   0.083433   0.038415  -0.075630  -0.079832
# 2010-03-15   0.108012   0.036795   0.018398  -0.080712  -0.109199  -0.084273
# ...               ...        ...        ...        ...        ...        ...
# 2023-12-13   0.023720        NaN        NaN        NaN        NaN        NaN
# 2023-12-20        NaN        NaN        NaN        NaN        NaN        NaN
# 2023-12-27        NaN        NaN        NaN        NaN        NaN        NaN
# 2024-01-03        NaN        NaN        NaN        NaN        NaN        NaN
# 2024-01-10        NaN        NaN        NaN        NaN        NaN        NaN
#
#             80day_ret  90day_ret
# Date
# 2010-01-15   0.049815  -0.048585
# 2010-01-29   0.020422  -0.011199
# 2010-02-12   0.038754   0.067820
# 2010-02-26  -0.064826  -0.117047
# 2010-03-15  -0.118101  -0.189318
# ...               ...        ...
# 2023-12-13        NaN        NaN
# 2023-12-20        NaN        NaN
# 2023-12-27        NaN        NaN
# 2024-01-03        NaN        NaN
# 2024-01-10        NaN        NaN
#
# [613 rows x 20 columns]

# %%
corr_df = pd.DataFrame()
for fname in df.columns:
    if fname not in ['10day_ret', '20day_ret', '30day_ret', '40day_ret', '50day_ret','60day_ret','70day_ret','80day_ret','90day_ret']:
        s = pd.Series(dtype=float)
        s['c_10'] = round(df[fname].corr(df["10day_ret"]),3)
        s['c_20'] = round(df[fname].corr(df["20day_ret"]),3)
        s['c_30'] = round(df[fname].corr(df["30day_ret"]),3)
        s['c_40'] = round(df[fname].corr(df["40day_ret"]),3)
        s['c_50'] = round(df[fname].corr(df["50day_ret"]),3)
        s['c_60'] = round(df[fname].corr(df["60day_ret"]),3)
        s['c_70'] = round(df[fname].corr(df["70day_ret"]),3)
        s['c_80'] = round(df[fname].corr(df["80day_ret"]),3)
        s['c_90'] = round(df[fname].corr(df["90day_ret"]),3)
        corr_df[fname] = s

corr_df
# Out:
#          mu     sd   skew   kurt    p10    p50    p90  prDec  prInc  \
# c_10 -0.033  0.059  0.056 -0.051 -0.058 -0.026  0.071  0.066  0.068
# c_20  0.016  0.103  0.080 -0.046 -0.091  0.011  0.131  0.102  0.124
# c_30 -0.015  0.133  0.053 -0.007 -0.121  0.008  0.158  0.141  0.151
# c_40 -0.075  0.139  0.039  0.014 -0.130 -0.032  0.153  0.162  0.149
# c_50 -0.108  0.177  0.031  0.016 -0.172 -0.021  0.188  0.197  0.183
# c_60 -0.118  0.188  0.036  0.007 -0.185 -0.019  0.198  0.205  0.193
# c_70 -0.108  0.181  0.042  0.002 -0.173 -0.025  0.193  0.197  0.186
# c_80 -0.111  0.197  0.045 -0.020 -0.192 -0.008  0.211  0.209  0.204
# c_90 -0.104  0.204  0.051 -0.029 -0.197  0.000  0.219  0.214  0.215
#
#       dec_plus_inc  dec_minus_inc
# c_10         0.068         -0.025
# c_20         0.116         -0.089
# c_30         0.149         -0.073
# c_40         0.158         -0.022
# c_50         0.193         -0.029
# c_60         0.203         -0.038
# c_70         0.195         -0.038
# c_80         0.210         -0.059
# c_90         0.219         -0.073

# %%
import statsmodels.api as sm
import seaborn as sns

select = df[['60day_ret','dec_plus_inc']].copy().dropna()

X = sm.add_constant(select.iloc[:,1])
y = select.iloc[:,0]
model = sm.OLS(y, X)
result = model.fit()
print('Regreesion results:')
print(result.summary())
# Out:
# Regreesion results:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              60day_ret   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     25.67
# Date:                Wed, 07 Feb 2024   Prob (F-statistic):           5.41e-07
# Time:                        19:03:50   Log-Likelihood:                 270.04
# No. Observations:                 600   AIC:                            -536.1
# Df Residuals:                     598   BIC:                            -527.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           -0.0279      0.012     -2.268      0.024      -0.052      -0.004
# dec_plus_inc     0.3349      0.066      5.067      0.000       0.205       0.465
# ==============================================================================
# Omnibus:                       14.591   Durbin-Watson:                   0.172
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               27.943
# Skew:                          -0.062   Prob(JB):                     8.56e-07
# Kurtosis:                       4.050   Cond. No.                         10.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
